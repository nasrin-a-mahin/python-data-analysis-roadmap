# %% [markdown]
# # Day 24 — Statistics Basics for Data Analysis
#
# ---
#
# ## 📌 Objectives
# - Understand why statistics is important in data analysis
# - Learn descriptive statistics
# - Calculate mean, median, mode
# - Understand variance & standard deviation
# - Analyze salary data statistically
# - Detect outliers using IQR
#
# ---
#
# ## 📂 Dataset Used
# - employee_salary.csv

# %%
# 1️⃣ Import Required Libraries
import pandas as pd
import numpy as np

# %%
# 2️⃣ Load Dataset
df = pd.read_csv("datasets/employee_salary.csv")

# Rename column
df.rename(columns={'Experience (Years)': 'Experience_Years'}, inplace=True)

df.head()

# %% [markdown]
# ## 3️⃣ What is Statistics?

# %% [markdown]
# Statistics helps us:
# - Summarize data
# - Identify patterns
# - Make data-driven decisions
# - Understand variability and distribution

# %% [markdown]
# ## 4️⃣ Measures of Central Tendency
# Mean, Median, Mode

# %%
mean_salary = df['Salary'].mean()
median_salary = df['Salary'].median()
mode_salary = df['Salary'].mode()[0]

print("Mean Salary:", mean_salary)
print("Median Salary:", median_salary)
print("Mode Salary:", mode_salary)

# %% [markdown]
# ## 5️⃣ Measures of Dispersion
# Range, Variance, Standard Deviation

# %%
salary_range = df['Salary'].max() - df['Salary'].min()
variance = df['Salary'].var()
std_dev = df['Salary'].std()

print("Salary Range:", salary_range)
print("Variance:", variance)
print("Standard Deviation:", std_dev)

# %% [markdown]
# ## 6️⃣ Salary Distribution Summary

# %%
df['Salary'].describe()

# %% [markdown]
# ## 7️⃣ Experience Statistics

# %%
df['Experience_Years'].describe()

# %% [markdown]
# ## 8️⃣ Salary Analysis by Gender (Statistics)

# %%
gender_stats = df.groupby('Gender')['Salary'].agg(
    Mean='mean',
    Median='median',
    Std_Dev='std',
    Min='min',
    Max='max'
)

gender_stats

# %% [markdown]
# ## 9️⃣ Salary Analysis by Position (Statistics)

# %%
position_stats = df.groupby('Position')['Salary'].agg(
    Mean='mean',
    Median='median',
    Std_Dev='std'
).sort_values(by='Mean', ascending=False)

position_stats

# %% [markdown]
# ## 🔟 Correlation
# Relationship between Experience and Salary

# %%
correlation = df['Experience_Years'].corr(df['Salary'])
print("Correlation between Experience and Salary:", correlation)

# %% [markdown]
# 📌 Interpretation:
# - Value close to +1 → strong positive relationship
# - Value close to 0 → weak relationship
# - Value close to -1 → negative relationship

# %% [markdown]
# ## 1️⃣1️⃣ Outlier Detection (IQR Method)

# %%
Q1 = df['Salary'].quantile(0.25)
Q3 = df['Salary'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['Salary'] < lower_bound) | (df['Salary'] > upper_bound)]
outliers

# %% [markdown]
# ## 1️⃣2️⃣ Z-Score (Optional Intro)

# %%
df['Salary_Zscore'] = (df['Salary'] - mean_salary) / std_dev
df[['Salary', 'Salary_Zscore']].head()

# %% [markdown]
# ## 1️⃣3️⃣ Key Statistical Insights

# %% [markdown]
# - Average salary is higher than median → right-skewed distribution
# - Salary increases with experience (positive correlation)
# - Some positions have high salary variance
# - Outliers exist at very high salary levels

# %% [markdown]
# ## 1️⃣4️⃣ Practice Exercises
#
# 1. Calculate mean & median experience
# 2. Find variance of experience years
# 3. Detect outliers in experience
# 4. Compare salary standard deviation by gender
# 5. Interpret correlation value in words
#
#
#
# ## ✅ End of Day 24 — Statistics Basics
