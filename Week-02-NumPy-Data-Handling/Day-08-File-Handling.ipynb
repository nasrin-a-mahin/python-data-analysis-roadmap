# %% [markdown]
# # 📘 Day-08: File Handling in Python
# 🎯 Why File Handling?
#
# Programs lose data when they stop running.
# File handling allows permanent storage and retrieval of data.
#
# Common real-world uses:
#
# =>Reading datasets (CSV, TXT, logs)
#
# =>Writing reports
#
# =>Storing user data
#
# =>Preprocessing data for NumPy & Pandas
#
# 📂 Types of Files
#
# Text files → .txt, .csv, .json
#
# Binary files → images, videos, .pdf, .exe

# %% [markdown]
# 🔹 Opening a File
# Syntax:
#
# file = open("filename", "mode")
#
#
# | Mode | Description                       |
# | ---- | --------------------------------- |
# | `r`  | Read (error if file not exists)   |
# | `w`  | Write (creates/overwrites)        |
# | `a`  | Append                            |
# | `x`  | Create new file (error if exists) |
# | `rb` | Read binary                       |
# | `wb` | Write binary                      |
# | `r+` | Read & write                      |
#
#
# 🔹 Closing a File
#
# file.close()
#
#
# ⚠️ Not closing files may cause:
#
# Memory leaks
#
# Data corruption

# %% [markdown]
# 🔹 Reading Files
# 1️⃣ read() – Read Entire File

# %%
file = open("data.txt", "r")
content = file.read()
print(content)
file.close()

#✔ Reads everything as a string
# Out:
# Line 1
# Line 2
# Line 3

# %% [markdown]
# 2️⃣ readline() – Read One Line

# %%
file = open("data.txt", "r")
line = file.readline()
print(line)
file.close()


#✔ Useful for large files
# Out:
# Line 1

# %% [markdown]
# 3️⃣ readlines() – Read All Lines as List

# %%
file = open("data.txt", "r")
lines = file.readlines()
print(lines)
file.close()
# Out:
# ['Line 1\n', 'Line 2\n', 'Line 3\n']

# %% [markdown]
# 4️⃣ Looping Through a File

# %%
file = open("data.txt")
for line in file:
    print(line.strip())
file.close()


#✔ Memory efficient
# Out:
# Line 1
# Line 2
# Line 3

# %% [markdown]
# 🔹 Writing Files
# 1️⃣ Write Mode (w)

# %%
file = open("data.txt", "w")
file.write("Python File Handling\n")
file.close()

# %% [markdown]
# ⚠️ Overwrites existing content
#
# 2️⃣ Append Mode (a)

# %%
file = open("data.txt", "a")
file.write("New Line Added\n")
file.close()

#✔ Keeps old data

# %% [markdown]
# 3️⃣ Writing Multiple Lines

# %%
lines = ["Line 1\n", "Line 2\n", "Line 3\n"]
file = open("data.txt", "w")
file.writelines(lines)
file.close()

# %% [markdown]
# 🔹 Using with Statement (BEST PRACTICE)

# %%
with open("data.txt", "r") as file:
    data = file.read()

# %% [markdown]
# ✔ No need to call close()
# ✔ Handles exceptions automatically

# %% [markdown]
# 🔹 File Pointer & seek()
# Checking Cursor Position

# %%
file = open("data.txt", "r")
print(file.tell())
# Out:
# 0

# %% [markdown]
# Move Cursor

# %%
file.seek(0)
# Out:
# 0

# %% [markdown]
# 🔹 Reading & Writing CSV Files
# Using csv Module

# %%
import csv

with open("data.csv", "r") as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age']
# ['Alice', '25']

# %% [markdown]
# Writing CSV

# %%
with open("data.csv", "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Name", "Age"])
    writer.writerow(["Alice", 25])

# %% [markdown]
# 🔹 Working with NumPy Files (Preview)
# Reading CSV into NumPy

# %%
import numpy as np

data = np.genfromtxt("data.csv", delimiter=",", skip_header=1)

#✔ Used heavily in your Mini-Project

# %% [markdown]
# 🔹 Binary File Handling
# Writing Binary File

# %%
with open("image.bin", "wb") as file:
    file.write(b"Binary Data")

# %% [markdown]
# Reading Binary File

# %%
with open("image.bin", "rb") as file:
    data = file.read()

# %% [markdown]
# 🔹 Exception Handling with Files

# %%
try:
    file = open("data.txt", "r")
    print(file.read())
except FileNotFoundError:
    print("File not found")
finally:
    file.close()


#✔ Prevents program crash
# Out:
# Line 1
# Line 2
# Line 3

# %% [markdown]
# 🔹 Common Mistakes & Solutions
#
# | Mistake          | Solution               |
# | ---------------- | ---------------------- |
# | File not closing | Use `with`             |
# | Overwriting data | Use `a`                |
# | Wrong path       | Use absolute path      |
# | Encoding error   | Use `encoding="utf-8"` |

# %% [markdown]
# 🔹 Encoding Example
#
# the encoding="utf-8" tells Python how to interpret the bytes in the file as text (characters).
#
# - Why this matters
#
# - Files are stored as bytes, but when you read a text file, Python must decode those bytes into characters (letters, symbols, emojis, etc.).
# The encoding parameter specifies which decoding rule to use
#
# - UTF-8 is a universal text encoding

# %%
with open("data.txt", "r", encoding="utf-8") as file:
    data = file.read()
    print(data)
# Out:
# Line 1
# Line 2
# Line 3
