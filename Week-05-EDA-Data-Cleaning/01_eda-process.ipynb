# %% [markdown]
# ## Objective
#
# ### Understand the dataset, identify data quality issues, and define a structured EDA roadmap before deep analysis.

# %% [markdown]
# ### 1️⃣ Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %% [markdown]
# ### 2️⃣ Load Dataset

# %%
df = pd.read_csv("retail_sales.csv")

# %% [markdown]
# ### 3️⃣ First Look at Data

# %%
df.head()

df.tail()


df.sample(5)

# %% [markdown]
# ### 4️⃣ Dataset Size & Shape

# %%
df.shape

# %% [markdown]
# - Rows represent individual customer orders
# - Columns represent customer, product, and transaction attributes

# %% [markdown]
# ### 5️⃣ Column Names & Data Types

# %%
df.columns

# %%
df.info()

# %% [markdown]
# ### 📌 Key Analyst Checks
#
# - Are dates stored as datetime?
# - Are numerical columns stored as object?
# - Any unexpected null values?

# %% [markdown]
# ### 6️⃣ Data Type Fixes (If Needed)

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'], errors='coerce')

# %% [markdown]
# ### 7️⃣ Statistical Summary

# %%
df.describe()

# %%
df.describe(include='object')

# %% [markdown]
# ### 📌 Business Interpretation
#
# - Sales show high variance → potential outliers
# - Discount values appear capped → possible business rule

# %% [markdown]
# ### 8️⃣ Missing Values Overview

# %%
df.isnull().sum()

# %%
(df.isnull().mean() * 100).round(2)

# %% [markdown]
# ### 📌 Initial Observation
#
# - Age and Region have missing values
# - Missing data < 10% → suitable for imputation

# %% [markdown]
# ### 9️⃣ Duplicate Records

# %%
df.duplicated().sum()

# %%
df[df.duplicated()]

# %% [markdown]
# ### 📌 Action Plan
#
# - Remove exact duplicates if found

# %% [markdown]
# ### 🔟 Unique Values Check (Categorical)

# %%
categorical_cols = df.select_dtypes(include='object').columns

for col in categorical_cols:
    print(col, ":", df[col].nunique())

# %% [markdown]
# 📌 Why This Matters
#
# - Detect inconsistent categories (e.g., 'Male' vs 'male')
# - Identify high-cardinality columns

# %% [markdown]
# ### 1️⃣1️⃣ Initial Visual Scan (Quick EDA)

# %%
df.hist(figsize=(12,8))
plt.show()

# %%
sns.boxplot(data=df[['Sales', 'Profit']])
plt.show()

# %% [markdown]
# 1️⃣2️⃣ Business Questions Definition
# ### Key Questions for EDA
# 1. What factors influence Sales and Profit?
# 2. How do discounts affect profitability?
# 3. Which product categories and regions perform best?
#
# 1️⃣3️⃣ EDA Roadmap (Final Cell)
# ### Next Steps
# 1. Handle missing values & outliers
# 2. Perform univariate analysis
# 3. Explore relationships (bivariate analysis)
# 4. Generate business insights & recommendations
